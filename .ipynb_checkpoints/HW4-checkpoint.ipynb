# %% [markdown]
# # Homework 4: Can you predict the Midterm Elections?
#
# Due: Monday, November 3, 2014 11:59 PM
#
# <a href=https://raw.githubusercontent.com/cs109/2014/master/homework/HW4.ipynb download=HW4.ipynb> Download this assignment</a>
#
# #### Submission Instructions
# To submit your homework, create a folder named lastname_firstinitial_hw# and place your IPython notebooks, data files, and any other files in this folder. Your IPython Notebooks should be completely executed with the results visible in the notebook. We should not have to run any code. Compress the folder (please use .zip compression) and submit to the CS109 dropbox in the appropriate folder. If we cannot access your work because these directions are not followed correctly, we will not grade your work. For the competition (problem 4), we will post a link on Piazza to a Google Form for you to submit your predictions.
#
#
# ---

# %% [markdown]
# ## Introduction
#
# **Add Introduction**
#
# You will use the [HuffPost Pollster API](http://elections.huffingtonpost.com/pollster/api) to extract the polls for the current 2014 Senate Midterm Elections and provide a final prediction of the result of each state.
#
# #### Data
#
# We will use the polls from the [2014 Senate Midterm Elections](http://elections.huffingtonpost.com/pollster) from the [HuffPost Pollster API](http://elections.huffingtonpost.com/pollster/api).
#
# ---

# %% [markdown]
# ## Problem 1: Data Wrangling
#
# We will read in the polls from the [2014 Senate Midterm Elections](http://elections.huffingtonpost.com/pollster) from the [HuffPost Pollster API](http://elections.huffingtonpost.com/pollster/api) and create a dictionary of DataFrames as well a master table information for each race.

# %%
import pollster as po

# %% [markdown]
# #### Problem 1(a)
#
# Read in [this JSON object](http://elections.huffingtonpost.com/pollster/api/charts/?topic=2014-senate) containing the polls for the 2014 Senate Elections using the HuffPost API. Call this JSON object `info`.  This JSON object is imported as a list in Python where each element contains the information for one race.  Use the function `type` to confirm the that `info` is a list.

# %%
import json,urllib.request
url = 'http://elections.huffingtonpost.com/pollster/api/charts/?topic=2014-senate'
with urllib.request.urlopen(url) as url:
    info=json.loads(url.read().decode())

# %%
type(info)
# Out:
# list

# %%
### Your code here ###
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#info = po.Api('2014 Senate Midterm Elections')
#info.charts_get()

# %% [markdown]
# #### Problem 1(b)
#
# For each element of the list in `info` extract the state. We should have one poll per state, but we do not. Why?
#
# **Hint**: Use the internet to find out information on the races in each state that has more than one entry. Eliminate entries of the list that represent races that are not happening.

# %%
info
# Out:
# [{'id': 571,
#   'title': '2014 Delaware Senate: Wade vs. Coons',
#   'slug': '2014-delaware-senate-wade-vs-coons',
#   'topic': '2014-senate',
#   'state': 'DE',
#   'short_title': '2014 Delaware Senate: Wade vs. Coons',
#   'election_date': '2014-11-04',
#   'poll_count': 5,
#   'last_updated': '2016-06-06T14:37:54.000Z',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-delaware-senate-wade-vs-coons',
#   'estimates': [{'choice': 'Coons',
#     'value': 56.0,
#     'lead_confidence': 99.9,
#     'first_name': 'Chris',
#     'last_name': 'Coons',
#     'party': 'Dem',
#     'incumbent': True},
#    {'choice': 'Wade',
#     'value': 34.0,
#     'lead_confidence': 0.0,
#     'first_name': 'Kevin',
#     'last_name': 'Wade',
#     'party': 'Rep',
#     'incumbent': False}]},
#  {'id': 570,
#   'title': '2014 Massachusetts Senate: Herr vs. Markey',
#   'slug': '2014-massachusetts-senate-herr-vs-markey',
#   'topic': '2014-senate',
#   'state': 'MA',
#   'short_title': '2014 Massachusetts Senate: Herr vs. Markey',
#   'election_date': '2014-11-04',
#   'poll_count': 13,
#   'last_updated': '2016-06-06T14:37:55.000Z',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-massachusetts-senate-herr-vs-markey',
#   'estimates': [{'choice': 'Markey',
#     'value': 54.1,
#     'lead_confidence': 99.9,
#     'first_name': 'Ed',
#     'last_name': 'Markey',
#     'party': 'Dem',
#     'incumbent': True},
#    {'choice': 'Herr',
#     'value': 33.4,
#     'lead_confidence': 0.0,
#     'first_name': 'Brian',
#     'last_name': 'Herr',
#     'party': 'Rep',
#     'incumbent': False},
#    {'choice': 'Other',
#     'value': 0.18,
#     'lead_confidence': None,
#     'first_name': None,
#     'last_name': None,
#     'party': 'N/A',
#     'incumbent': False}]},
#  {'id': 569,
#   'title': '2014 Rhode Island Senate: Zaccaria vs. Reed',
#   'slug': '2014-rhode-island-senate-zaccaria-vs-reed',
#   'topic': '2014-senate',
#   'state': 'RI',
#   'short_title': '2014 Rhode Island Senate: Zaccaria vs. Reed',
#   'election_date': '2014-11-04',
#   'poll_count': 4,
#   'last_updated': '2016-06-06T14:37:55.000Z',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-rhode-island-senate-zaccaria-vs-reed',
#   'estimates': []},
#  {'id': 568,
#   'title': '2014 Montana Senate: Daines vs. Curtis',
#   'slug': '2014-montana-senate-daines-vs-curtis',
#   'topic': '2014-senate',
#   'state': 'MT',
#   'short_title': '2014 Montana Senate: Daines vs. Curtis',
#   'election_date': '2014-11-04',
#   'poll_count': 7,
#   'last_updated': '2016-06-06T14:37:56.000Z',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-montana-senate-daines-vs-curtis',
#   'estimates': [{'choice': 'Daines',
#     'value': 53.8,
#     'lead_confidence': 99.9,
#     'first_name': 'Steve',
#     'last_name': 'Daines',
#     'party': 'Rep',
#     'incumbent': False},
#    {'choice': 'Curtis',
#     'value': 36.1,
#     'lead_confidence': 0.0,
#     'first_name': 'Amanda',
#     'last_name': 'Curtis',
#     'party': 'Dem',
#     'incumbent': False}]},
#  {'id': 567,
#   'title': '2014 Oklahoma Senate: Lankford vs. Johnson',
#   'slug': '2014-oklahoma-senate-lankford-vs-johnson',
#   'topic': '2014-senate',
#   'state': 'OK',
#   'short_title': '2014 Oklahoma Senate: Lankford vs. Johnson',
#   'election_date': '2014-11-04',
#   'poll_count': 8,
#   'last_updated': '2016-06-06T14:37:56.000Z',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-oklahoma-senate-lankford-vs-johnson',
#   'estimates': [{'choice': 'Lankford',
#     'value': 62.4,
#     'lead_confidence': 100.0,
#     'first_name': 'James',
#     'last_name': 'Lankford',
#     'party': 'Rep',
#     'incumbent': False},
#    {'choice': 'Johnson',
#     'value': 28.6,
#     'lead_confidence': 0.0,
#     'first_name': 'Connie',
#     'last_name': 'Johnson',
#     'party': 'Dem',
#     'incumbent': False},
#    {'choice': 'Other',
#     'value': 2.3,
#     'lead_confidence': None,
#     'first_name': None,
#     'last_name': None,
#     'party': 'N/A',
#     'incumbent': False}]},
#  {'id': 566,
#   'title': '2014 Hawaii Senate: Cavasso vs. Schatz',
#   'slug': '2014-hawaii-senate-cavasso-vs-schatz',
#   'topic': '2014-senate',
#   'state': 'HI',
#   'short_title': '2014 Hawaii Senate',
#   'election_date': '2014-11-04',
#   'poll_count': 8,
#   'last_updated': '2016-06-06T14:37:57.000Z',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-hawaii-senate-cavasso-vs-schatz',
#   'estimates': [{'choice': 'Schatz',
#     'value': 67.9,
#     'lead_confidence': 100.0,
#     'first_name': 'Brian',
#     'last_name': 'Schatz',
#     'party': 'Dem',
#     'incumbent': True},
#    {'choice': 'Cavasso',
#     'value': 20.2,
#     'lead_confidence': 0.0,
#     'first_name': 'Campbell',
#     'last_name': 'Cavasso',
#     'party': 'Rep',
#     'incumbent': False},
#    {'choice': 'Other',
#     'value': 1.0,
#     'lead_confidence': None,
#     'first_name': None,
#     'last_name': None,
#     'party': 'N/A',
#     'incumbent': False}]},
#  {'id': 560,
#   'title': '2014 Kansas Senate',
#   'slug': '2014-kansas-senate-roberts-vs-orman-vs-taylor',
#   'topic': '2014-senate',
#   'state': 'KS',
#   'short_title': '2014 Kansas Senate',
#   'election_date': '2014-11-04',
#   'poll_count': 27,
#   'last_updated': '2016-06-06T14:38:02.000Z',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-kansas-senate-roberts-vs-orman-vs-taylor',
#   'estimates': [{'choice': 'Orman',
#     'value': 45.0,
#     'lead_confidence': 25.9,
#     'first_name': 'Greg',
#     'last_name': 'Orman',
#     'party': 'ind',
#     'incumbent': False},
#    {'choice': 'Roberts',
#     'value': 46.7,
#     'lead_confidence': 74.1,
#     'first_name': 'Pat',
#     'last_name': 'Roberts',
#     'party': 'Rep',
#     'incumbent': True},
#    {'choice': 'Other',
#     'value': 3.66,
#     'lead_confidence': None,
#     'first_name': None,
#     'last_name': None,
#     'party': 'N/A',
#     'incumbent': False}]},
#  {'id': 555,
#   'title': '2014 Wyoming Senate: Enzi vs. Hardy',
#   'slug': '2014-wyoming-senate',
#   'topic': '2014-senate',
#   'state': 'WY',
#   'short_title': '2014 Wyoming Senate',
#   'election_date': '2014-11-04',
#   'poll_count': 5,
#   'last_updated': '2016-06-06T14:38:05.000Z',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-wyoming-senate',
#   'estimates': [{'choice': 'Enzi',
#     'value': 68.9,
#     'lead_confidence': 100.0,
#     'first_name': 'Mike',
#     'last_name': 'Enzi',
#     'party': 'Rep',
#     'incumbent': True},
#    {'choice': 'Hardy',
#     'value': 25.5,
#     'lead_confidence': 0.0,
#     'first_name': 'Charlie',
#     'last_name': 'Hardy',
#     'party': 'Dem',
#     'incumbent': False}]},
#  {'id': 550,
#   'title': '2014 Tennessee Senate: Alexander vs. Ball',
#   'slug': '2014-tennessee-senate-alexander-vs-ball',
#   'topic': '2014-senate',
#   'state': 'TN',
#   'short_title': '2014 Tennessee Senate',
#   'election_date': '2014-11-04',
#   'poll_count': 6,
#   'last_updated': '2016-06-06T14:38:08.000Z',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-tennessee-senate-alexander-vs-ball',
#   'estimates': [{'choice': 'Alexander',
#     'value': 55.3,
#     'lead_confidence': 100.0,
#     'first_name': 'Lamar',
#     'last_name': 'Alexander',
#     'party': 'Rep',
#     'incumbent': True},
#    {'choice': 'Ball',
#     'value': 32.5,
#     'lead_confidence': 0.0,
#     'first_name': 'Gordon',
#     'last_name': 'Ball',
#     'party': 'Dem',
#     'incumbent': False},
#    {'choice': 'Other',
#     'value': 1.16,
#     'lead_confidence': None,
#     'first_name': None,
#     'last_name': None,
#     'party': 'N/A',
#     'incumbent': False}]},
#  {'id': 543,
#   'title': '2014 Idaho Senate: Risch vs. Mitchell',
#   'slug': '2014-idaho-senate-risch-vs-mitchell',
#   'topic': '2014-senate',
#   'state': 'ID',
#   'short_title': '2014 Idaho Senate',
#   'election_date': '2014-11-04',
#   'poll_count': 6,
#   'last_updated': '2016-06-06T14:38:11.000Z',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-idaho-senate-risch-vs-mitchell',
#   'estimates': [{'choice': 'Risch',
#     'value': 57.7,
#     'lead_confidence': 100.0,
#     'first_name': 'Jim',
#     'last_name': 'Risch',
#     'party': 'Rep',
#     'incumbent': True},
#    {'choice': 'Mitchell',
#     'value': 29.2,
#     'lead_confidence': 0.0,
#     'first_name': 'Nels',
#     'last_name': 'Mitchell',
#     'party': 'Dem',
#     'incumbent': False}]},
#  {'id': 538,
#   'title': '2014 New Jersey Senate: Bell vs. Booker',
#   'slug': '2014-new-jersey-senate-bell-vs-booker',
#   'topic': '2014-senate',
#   'state': 'NJ',
#   'short_title': '2014 New Jersey Senate',
#   'election_date': '2014-11-04',
#   'poll_count': 15,
#   'last_updated': '2016-06-06T14:38:14.000Z',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-new-jersey-senate-bell-vs-booker',
#   'estimates': [{'choice': 'Booker',
#     'value': 52.7,
#     'lead_confidence': 100.0,
#     'first_name': 'Cory',
#     'last_name': 'Booker',
#     'party': 'Dem',
#     'incumbent': True},
#    {'choice': 'Bell',
#     'value': 37.4,
#     'lead_confidence': 0.0,
#     'first_name': 'Jeff',
#     'last_name': 'Bell',
#     'party': 'Rep',
#     'incumbent': False},
#    {'choice': 'Other',
#     'value': 0.76,
#     'lead_confidence': None,
#     'first_name': None,
#     'last_name': None,
#     'party': 'N/A',
#     'incumbent': False}]},
#  {'id': 536,
#   'title': '2014 New Mexico Senate: Weh vs. Udall',
#   'slug': '2014-new-mexico-senate-weh-vs-udall',
#   'topic': '2014-senate',
#   'state': 'NM',
#   'short_title': '2014 New Mexico Senate',
#   'election_date': '2014-11-04',
#   'poll_count': 12,
#   'last_updated': '2016-06-06T14:38:15.000Z',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-new-mexico-senate-weh-vs-udall',
#   'estimates': [{'choice': 'Udall',
#     'value': 52.1,
#     'lead_confidence': 99.9,
#     'first_name': 'Tom',
#     'last_name': 'Udall',
#     'party': 'Dem',
#     'incumbent': True},
#    {'choice': 'Weh',
#     'value': 39.6,
#     'lead_confidence': 0.1,
#     'first_name': 'Allen',
#     'last_name': 'Weh',
#     'party': 'Rep',
#     'incumbent': False},
#    {'choice': 'Other',
#     'value': 1.0,
#     'lead_confidence': None,
#     'first_name': None,
#     'last_name': None,
#     'party': 'N/A',
#     'incumbent': False}]},
#  {'id': 533,
#   'title': '2014 Oklahoma Senate: Inhofe vs. Silverstein',
#   'slug': '2014-oklahoma-senate-inhofe-vs-silverstein',
#   'topic': '2014-senate',
#   'state': 'OK',
#   'short_title': '2014 Oklahoma Senate: Inhofe vs. Silverstein',
#   'election_date': '2014-11-04',
#   'poll_count': 8,
#   'last_updated': '2016-06-06T14:38:18.000Z',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-oklahoma-senate-inhofe-vs-silverstein',
#   'estimates': [{'choice': 'Inhofe',
#     'value': 64.4,
#     'lead_confidence': 100.0,
#     'first_name': 'Jim',
#     'last_name': 'Inhofe',
#     'party': 'Rep',
#     'incumbent': True},
#    {'choice': 'Silverstein',
#     'value': 27.1,
#     'lead_confidence': 0.0,
#     'first_name': 'Matt',
#     'last_name': 'Silverstein',
#     'party': 'Dem',
#     'incumbent': False},
#    {'choice': 'Other',
#     'value': 2.76,
#     'lead_confidence': None,
#     'first_name': None,
#     'last_name': None,
#     'party': 'N/A',
#     'incumbent': False}]},
#  {'id': 531,
#   'title': '2014 South Carolina Senate: Scott vs. Dickerson',
#   'slug': '2014-south-carolina-senate-scott-vs-dickerson',
#   'topic': '2014-senate',
#   'state': 'SC',
#   'short_title': '2014 South Carolina Senate: Scott vs. Dickerson',
#   'election_date': '2014-11-04',
#   'poll_count': 6,
#   'last_updated': '2016-06-06T14:38:19.000Z',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-south-carolina-senate-scott-vs-dickerson',
#   'estimates': [{'choice': 'Scott',
#     'value': 55.1,
#     'lead_confidence': 100.0,
#     'first_name': 'Tim',
#     'last_name': 'Scott',
#     'party': 'Rep',
#     'incumbent': True},
#    {'choice': 'Dickerson',
#     'value': 27.5,
#     'lead_confidence': 0.0,
#     'first_name': 'Joyce',
#     'last_name': 'Dickerson',
#     'party': 'Dem',
#     'incumbent': False}]},
#  {'id': 530,
#   'title': '2014 South Carolina Senate: Graham vs. Hutto',
#   'slug': '2014-south-carolina-senate-graham-vs-hutto',
#   'topic': '2014-senate',
#   'state': 'SC',
#   'short_title': '2014 South Carolina Senate: Graham vs. Hutto',
#   'election_date': '2014-11-04',
#   'poll_count': 8,
#   'last_updated': '2016-06-06T14:38:19.000Z',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-south-carolina-senate-graham-vs-hutto',
#   'estimates': [{'choice': 'Graham',
#     'value': 47.6,
#     'lead_confidence': 99.9,
#     'first_name': 'Lindsey',
#     'last_name': 'Graham',
#     'party': 'Rep',
#     'incumbent': True},
#    {'choice': 'Hutto',
#     'value': 29.5,
#     'lead_confidence': 0.0,
#     'first_name': 'Brad',
#     'last_name': 'Hutto',
#     'party': 'Dem',
#     'incumbent': False},
#    {'choice': 'Other',
#     'value': 10.0,
#     'lead_confidence': None,
#     'first_name': None,
#     'last_name': None,
#     'party': 'N/A',
#     'incumbent': False}]},
#  {'id': 528,
#   'title': '2014 Texas Senate: Cornyn vs. Alameel',
#   'slug': '2014-texas-senate-cornyn-vs-alameel',
#   'topic': '2014-senate',
#   'state': 'TX',
#   'short_title': '2014 Texas Senate',
#   'election_date': '2014-11-04',
#   'poll_count': 10,
#   'last_updated': '2016-06-06T14:38:20.000Z',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-texas-senate-cornyn-vs-alameel',
#   'estimates': [{'choice': 'Cornyn',
#     'value': 54.0,
#     'lead_confidence': 100.0,
#     'first_name': 'John',
#     'last_name': 'Cornyn',
#     'party': 'Rep',
#     'incumbent': True},
#    {'choice': 'Alameel',
#     'value': 30.9,
#     'lead_confidence': 0.0,
#     'first_name': 'David',
#     'last_name': 'Alameel',
#     'party': 'Dem',
#     'incumbent': False},
#    {'choice': 'Other',
#     'value': 0.8,
#     'lead_confidence': None,
#     'first_name': None,
#     'last_name': None,
#     'party': 'N/A',
#     'incumbent': False}]},
#  {'id': 523,
#   'title': '2014 Minnesota Senate: McFadden vs. Franken',
#   'slug': '2014-minnesota-senate-mcfadden-vs-franken',
#   'topic': '2014-senate',
#   'state': 'MN',
#   'short_title': '2014 Minnesota Senate',
#   'election_date': '2014-11-04',
#   'poll_count': 21,
#   'last_updated': '2016-06-06T14:38:23.000Z',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-minnesota-senate-mcfadden-vs-franken',
#   'estimates': [{'choice': 'Franken',
#     'value': 51.5,
#     'lead_confidence': 100.0,
#     'first_name': 'Al',
#     'last_name': 'Franken',
#     'party': 'Dem',
#     'incumbent': True},
#    {'choice': 'McFadden',
#     'value': 39.9,
#     'lead_confidence': 0.0,
#     'first_name': 'Mike',
#     'last_name': 'McFadden',
#     'party': 'Rep',
#     'incumbent': False},
#    {'choice': 'Other',
#     'value': 4.87,
#     'lead_confidence': None,
#     'first_name': None,
#     'last_name': None,
#     'party': 'N/A',
#     'incumbent': False}]},
#  {'id': 522,
#   'title': '2014 Maine Senate: Collins vs. Bellows',
#   'slug': '2014-maine-senate-collins-vs-bellows',
#   'topic': '2014-senate',
#   'state': 'ME',
#   'short_title': '2014 Maine Senate',
#   'election_date': '2014-11-04',
#   'poll_count': 16,
#   'last_updated': '2016-06-06T14:38:23.000Z',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-maine-senate-collins-vs-bellows',
#   'estimates': [{'choice': 'Collins',
#     'value': 61.1,
#     'lead_confidence': 100.0,
#     'first_name': 'Susan',
#     'last_name': 'Collins',
#     'party': 'Rep',
#     'incumbent': True},
#    {'choice': 'Bellows',
#     'value': 34.1,
#     'lead_confidence': 0.0,
#     'first_name': 'Shenna',
#     'last_name': 'Bellows',
#     'party': 'Dem',
#     'incumbent': False},
#    {'choice': 'Other',
#     'value': 1.5,
#     'lead_confidence': None,
#     'first_name': None,
#     'last_name': None,
#     'party': 'N/A',
#     'incumbent': False}]},
#  {'id': 511,
#   'title': '2014 South Dakota Senate: Rounds vs. Weiland',
#   'slug': '2014-south-dakota-senate-rounds-vs-weiland',
#   'topic': '2014-senate',
#   'state': 'SD',
#   'short_title': '2014 South Dakota Senate',
#   'election_date': '2014-11-04',
#   'poll_count': 25,
#   'last_updated': '2016-06-06T14:38:28.000Z',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-south-dakota-senate-rounds-vs-weiland',
#   'estimates': [{'choice': 'Rounds',
#     'value': 43.4,
#     'lead_confidence': 99.9,
#     'first_name': 'Mike',
#     'last_name': 'Rounds',
#     'party': 'Rep',
#     'incumbent': False},
#    {'choice': 'Weiland',
#     'value': 29.7,
#     'lead_confidence': 0.0,
#     'first_name': 'Rick',
#     'last_name': 'Weiland',
#     'party': 'Dem',
#     'incumbent': False},
#    {'choice': 'Pressler',
#     'value': 17.7,
#     'lead_confidence': None,
#     'first_name': 'Larry',
#     'last_name': 'Pressler',
#     'party': 'Ind',
#     'incumbent': False},
#    {'choice': 'Other',
#     'value': 1.65,
#     'lead_confidence': None,
#     'first_name': None,
#     'last_name': None,
#     'party': 'N/A',
#     'incumbent': False}]},
#  {'id': 505,
#   'title': '2014 Nebraska Senate: Sasse vs. Domina',
#   'slug': '2014-nebraska-senate-sasse-vs-domina',
#   'topic': '2014-senate',
#   'state': 'NE',
#   'short_title': '2014 Nebraska Senate: Sasse vs. Domina',
#   'election_date': '2014-11-04',
#   'poll_count': 6,
#   'last_updated': '2016-06-06T14:38:32.000Z',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-nebraska-senate-sasse-vs-domina',
#   'estimates': [{'choice': 'Sasse',
#     'value': 57.2,
#     'lead_confidence': 100.0,
#     'first_name': 'Ben',
#     'last_name': 'Sasse',
#     'party': 'Rep',
#     'incumbent': False},
#    {'choice': 'Domina',
#     'value': 30.3,
#     'lead_confidence': 0.0,
#     'first_name': 'David',
#     'last_name': 'Domina',
#     'party': 'Dem',
#     'incumbent': False}]},
#  {'id': 497,
#   'title': '2014 Georgia Senate: Perdue vs. Nunn',
#   'slug': '2014-georgia-senate-perdue-vs-nunn',
#   'topic': '2014-senate',
#   'state': 'GA',
#   'short_title': '2014 Georgia Senate',
#   'election_date': '2014-11-04',
#   'poll_count': 51,
#   'last_updated': '2016-07-08T16:29:13.000Z',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-georgia-senate-perdue-vs-nunn',
#   'estimates': [{'choice': 'Perdue',
#     'value': 47.4,
#     'lead_confidence': 99.9,
#     'first_name': 'David',
#     'last_name': 'Perdue',
#     'party': 'Rep',
#     'incumbent': False},
#    {'choice': 'Nunn',
#     'value': 43.4,
#     'lead_confidence': 0.0,
#     'first_name': 'Michelle',
#     'last_name': 'Nunn',
#     'party': 'Dem',
#     'incumbent': False},
#    {'choice': 'Swafford',
#     'value': 3.7,
#     'lead_confidence': None,
#     'first_name': 'Amanda',
#     'last_name': 'Swafford',
#     'party': 'Lib',
#     'incumbent': False},
#    {'choice': 'Other',
#     'value': 1.6,
#     'lead_confidence': None,
#     'first_name': None,
#     'last_name': None,
#     'party': 'N/A',
#     'incumbent': False}]},
#  {'id': 489,
#   'title': '2014 Oregon Senate: Wehby vs. Merkley',
#   'slug': '2014-oregon-senate-wehby-vs-merkley',
#   'topic': '2014-senate',
#   'state': 'OR',
#   'short_title': '2014 Oregon Senate',
#   'election_date': '2014-11-04',
#   'poll_count': 19,
#   'last_updated': '2016-06-06T14:38:40.000Z',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-oregon-senate-wehby-vs-merkley',
#   'estimates': [{'choice': 'Merkley',
#     'value': 52.7,
#     'lead_confidence': 100.0,
#     'first_name': 'Jeff',
#     'last_name': 'Merkley',
#     'party': 'Dem',
#     'incumbent': True},
#    {'choice': 'Wehby',
#     'value': 35.2,
#     'lead_confidence': 0.0,
#     'first_name': 'Monica',
#     'last_name': 'Wehby',
#     'party': 'Rep',
#     'incumbent': False},
#    {'choice': 'Other',
#     'value': 4.54,
#     'lead_confidence': None,
#     'first_name': None,
#     'last_name': None,
#     'party': 'N/A',
#     'incumbent': False}]},
#  {'id': 469,
#   'title': '2014 Mississippi Senate: Cochran vs. Childers',
#   'slug': '2014-mississippi-senate-cochran-vs-childers',
#   'topic': '2014-senate',
#   'state': 'MS',
#   'short_title': '2014 Mississippi Senate',
#   'election_date': '2014-11-04',
#   'poll_count': 8,
#   'last_updated': '2016-06-06T14:38:52.000Z',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-mississippi-senate-cochran-vs-childers',
#   'estimates': [{'choice': 'Cochran',
#     'value': 44.2,
#     'lead_confidence': 99.9,
#     'first_name': 'Thad',
#     'last_name': 'Cochran',
#     'party': 'Rep',
#     'incumbent': True},
#    {'choice': 'Childers',
#     'value': 26.7,
#     'lead_confidence': 0.0,
#     'first_name': 'Travis',
#     'last_name': 'Childers',
#     'party': 'Dem',
#     'incumbent': False},
#    {'choice': 'Other',
#     'value': 9.0,
#     'lead_confidence': None,
#     'first_name': None,
#     'last_name': None,
#     'party': 'N/A',
#     'incumbent': False}]},
#  {'id': 463,
#   'title': '2014 Iowa Senate: Ernst vs. Braley',
#   'slug': '2014-iowa-senate-ernst-vs-braley',
#   'topic': '2014-senate',
#   'state': 'IA',
#   'short_title': '2014 Iowa Senate',
#   'election_date': '2014-11-04',
#   'poll_count': 55,
#   'last_updated': '2016-07-08T16:29:30.000Z',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-iowa-senate-ernst-vs-braley',
#   'estimates': [{'choice': 'Ernst',
#     'value': 48.1,
#     'lead_confidence': 94.1,
#     'first_name': 'Joni',
#     'last_name': 'Ernst',
#     'party': 'Rep',
#     'incumbent': False},
#    {'choice': 'Braley',
#     'value': 45.6,
#     'lead_confidence': 5.9,
#     'first_name': 'Bruce',
#     'last_name': 'Braley',
#     'party': 'Dem',
#     'incumbent': False},
#    {'choice': 'Other',
#     'value': 1.76,
#     'lead_confidence': None,
#     'first_name': None,
#     'last_name': None,
#     'party': 'N/A',
#     'incumbent': False}]},
#  {'id': 459,
#   'title': '2014 Alaska Senate: Sullivan vs. Begich',
#   'slug': '2014-alaska-senate-sullivan-vs-begich',
#   'topic': '2014-senate',
#   'state': 'AK',
#   'short_title': '2014 Alaska Senate: Sullivan vs. Begich',
#   'election_date': '2014-11-04',
#   'poll_count': 35,
#   'last_updated': '2016-06-06T14:38:57.000Z',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-alaska-senate-sullivan-vs-begich',
#   'estimates': [{'choice': 'Sullivan',
#     'value': 50.0,
#     'lead_confidence': 99.8,
#     'first_name': 'Dan',
#     'last_name': 'Sullivan',
#     'party': 'Rep',
#     'incumbent': False},
#    {'choice': 'Begich',
#     'value': 45.7,
#     'lead_confidence': 0.2,
#     'first_name': 'Mark',
#     'last_name': 'Begich',
#     'party': 'Dem',
#     'incumbent': True},
#    {'choice': 'Other',
#     'value': 4.98,
#     'lead_confidence': None,
#     'first_name': None,
#     'last_name': None,
#     'party': 'N/A',
#     'incumbent': False}]},
#  {'id': 457,
#   'title': '2014 Illinois Senate: Oberweis vs. Durbin',
#   'slug': '2014-illinois-senate-oberweis-vs-durbin',
#   'topic': '2014-senate',
#   'state': 'IL',
#   'short_title': 'IL Senate: Oberweis vs. Durbin',
#   'election_date': '2014-11-04',
#   'poll_count': 15,
#   'last_updated': '2016-06-06T14:38:58.000Z',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-illinois-senate-oberweis-vs-durbin',
#   'estimates': [{'choice': 'Durbin',
#     'value': 51.6,
#     'lead_confidence': 100.0,
#     'first_name': 'Dick',
#     'last_name': 'Durbin',
#     'party': 'Dem',
#     'incumbent': True},
#    {'choice': 'Oberweis',
#     'value': 38.7,
#     'lead_confidence': 0.0,
#     'first_name': 'Jim',
#     'last_name': 'Oberweis',
#     'party': 'Rep',
#     'incumbent': False},
#    {'choice': 'Other',
#     'value': 3.12,
#     'lead_confidence': None,
#     'first_name': None,
#     'last_name': None,
#     'party': 'N/A',
#     'incumbent': False}]},
#  {'id': 453,
#   'title': '2014 Colorado Senate: Gardner vs. Udall',
#   'slug': '2014-colorado-senate-gardner-vs-udall',
#   'topic': '2014-senate',
#   'state': 'CO',
#   'short_title': '2014 Colorado Senate',
#   'election_date': '2014-11-04',
#   'poll_count': 54,
#   'last_updated': '2016-08-15T15:22:09.000Z',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-colorado-senate-gardner-vs-udall',
#   'estimates': [{'choice': 'Gardner',
#     'value': 49.2,
#     'lead_confidence': 93.2,
#     'first_name': 'Cory',
#     'last_name': 'Gardner',
#     'party': 'Rep',
#     'incumbent': False},
#    {'choice': 'Udall',
#     'value': 47.3,
#     'lead_confidence': 6.8,
#     'first_name': 'Mark',
#     'last_name': 'Udall',
#     'party': 'Dem',
#     'incumbent': True},
#    {'choice': 'Other',
#     'value': '4.892640752232218',
#     'lead_confidence': None,
#     'first_name': None,
#     'last_name': None,
#     'party': 'N/A',
#     'incumbent': False},
#    {'choice': 'Undecided',
#     'value': 3.5,
#     'lead_confidence': None,
#     'first_name': None,
#     'last_name': None,
#     'party': 'N/A',
#     'incumbent': False}]},
#  {'id': 444,
#   'title': '2014 Virginia Senate: Gillespie vs. Warner',
#   'slug': '2014-virginia-senate-gillespie-vs-warner',
#   'topic': '2014-senate',
#   'state': 'VA',
#   'short_title': '2014 Virginia Senate',
#   'election_date': '2014-11-04',
#   'poll_count': 22,
#   'last_updated': '2016-06-06T14:39:10.000Z',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-virginia-senate-gillespie-vs-warner',
#   'estimates': [{'choice': 'Warner',
#     'value': 50.3,
#     'lead_confidence': 99.9,
#     'first_name': 'Mark',
#     'last_name': 'Warner',
#     'party': 'Dem',
#     'incumbent': True},
#    {'choice': 'Gillespie',
#     'value': 38.7,
#     'lead_confidence': 0.0,
#     'first_name': 'Ed',
#     'last_name': 'Gillespie',
#     'party': 'Rep',
#     'incumbent': False},
#    {'choice': 'Sarvis',
#     'value': 2.0,
#     'lead_confidence': None,
#     'first_name': 'Robert',
#     'last_name': 'Sarvis',
#     'party': 'Lib',
#     'incumbent': False}]},
#  {'id': 438,
#   'title': '2014 North Carolina Senate: Tillis vs. Hagan',
#   'slug': '2014-north-carolina-senate-tillis-vs-hagan',
#   'topic': '2014-senate',
#   'state': 'NC',
#   'short_title': '2014 North Carolina Senate',
#   'election_date': '2014-11-04',
#   'poll_count': 76,
#   'last_updated': '2016-07-08T16:29:46.000Z',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-north-carolina-senate-tillis-vs-hagan',
#   'estimates': [{'choice': 'Hagan',
#     'value': 46.3,
#     'lead_confidence': 69.7,
#     'first_name': 'Kay',
#     'last_name': 'Hagan',
#     'party': 'Dem',
#     'incumbent': True},
#    {'choice': 'Tillis',
#     'value': 45.7,
#     'lead_confidence': 30.3,
#     'first_name': 'Thom',
#     'last_name': 'Tillis',
#     'party': 'Rep',
#     'incumbent': False},
#    {'choice': 'Haugh',
#     'value': 4.9,
#     'lead_confidence': None,
#     'first_name': 'Sean',
#     'last_name': 'Haugh',
#     'party': 'Lib',
#     'incumbent': False},
#    {'choice': 'Other',
#     'value': 1.85,
#     'lead_confidence': None,
#     'first_name': None,
#     'last_name': None,
#     'party': 'N/A',
#     'incumbent': False}]},
#  {'id': 422,
#   'title': '2014 New Hampshire Senate: Bass vs. Shaheen',
#   'slug': '2014-new-hampshire-senate-bass-vs-shaheen',
#   'topic': '2014-senate',
#   'state': 'NH',
#   'short_title': 'NH Senate: Bass vs. Shaheen',
#   'election_date': '2014-11-04',
#   'poll_count': 3,
#   'last_updated': '2016-06-06T14:39:23.000Z',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-new-hampshire-senate-bass-vs-shaheen',
#   'estimates': []},
#  {'id': 418,
#   'title': '2014 West Virginia Senate: Capito vs. Tennant',
#   'slug': '2014-west-virginia-senate-capito-vs-tennant',
#   'topic': '2014-senate',
#   'state': 'WV',
#   'short_title': '2014 West Virginia Senate',
#   'election_date': '2014-11-04',
#   'poll_count': 14,
#   'last_updated': '2016-09-02T12:37:09.000Z',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-west-virginia-senate-capito-vs-tennant',
#   'estimates': [{'choice': 'Capito',
#     'value': 53.5,
#     'lead_confidence': 100.0,
#     'first_name': 'Shelley',
#     'last_name': 'Moore Capito',
#     'party': 'Rep',
#     'incumbent': False},
#    {'choice': 'Tennant',
#     'value': 35.8,
#     'lead_confidence': 0.0,
#     'first_name': 'Natalie',
#     'last_name': 'Tennant',
#     'party': 'Dem',
#     'incumbent': False},
#    {'choice': 'Undecided',
#     'value': 10.7,
#     'lead_confidence': None,
#     'first_name': None,
#     'last_name': None,
#     'party': 'N/A',
#     'incumbent': False},
#    {'choice': 'Other',
#     'value': '0.27212787062756977',
#     'lead_confidence': None,
#     'first_name': None,
#     'last_name': None,
#     'party': 'N/A',
#     'incumbent': False}]},
#  {'id': 414,
#   'title': '2014 New Hampshire Senate: Brown vs. Shaheen',
#   'slug': '2014-new-hampshire-senate-brown-vs-shaheen',
#   'topic': '2014-senate',
#   'state': 'NH',
#   'short_title': '2014 New Hampshire Senate',
#   'election_date': '2014-11-04',
#   'poll_count': 62,
#   'last_updated': '2016-07-08T16:30:01.000Z',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-new-hampshire-senate-brown-vs-shaheen',
#   'estimates': [{'choice': 'Shaheen',
#     'value': 47.6,
#     'lead_confidence': 89.6,
#     'first_name': 'Jeanne',
#     'last_name': 'Shaheen',
#     'party': 'Dem',
#     'incumbent': True},
#    {'choice': 'Brown',
#     'value': 46.2,
#     'lead_confidence': 10.4,
#     'first_name': 'Scott',
#     'last_name': 'Brown',
#     'party': 'Rep',
#     'incumbent': False},
#    {'choice': 'Other',
#     'value': 1.26,
#     'lead_confidence': None,
#     'first_name': None,
#     'last_name': None,
#     'party': 'N/A',
#     'incumbent': False}]},
#  {'id': 411,
#   'title': '2014 Louisiana Senate: Cassidy vs. Landrieu',
#   'slug': '2014-louisiana-senate-cassidy-vs-landrieu',
#   'topic': '2014-senate',
#   'state': 'LA',
#   'short_title': '2014 Louisiana Senate',
#   'election_date': '2014-12-06',
#   'poll_count': 41,
#   'last_updated': '2016-06-06T14:39:31.000Z',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-louisiana-senate-cassidy-vs-landrieu',
#   'estimates': [{'choice': 'Cassidy',
#     'value': 55.5,
#     'lead_confidence': 100.0,
#     'first_name': 'Bill',
#     'last_name': 'Cassidy',
#     'party': 'Rep',
#     'incumbent': False},
#    {'choice': 'Landrieu',
#     'value': 40.7,
#     'lead_confidence': 0.0,
#     'first_name': 'Mary',
#     'last_name': 'Landrieu',
#     'party': 'Dem',
#     'incumbent': True}]},
#  {'id': 407,
#   'title': '2014 Michigan Senate: Land vs. Peters',
#   'slug': '2014-michigan-senate-land-vs-peters',
#   'topic': '2014-senate',
#   'state': 'MI',
#   'short_title': '2014 Michigan Senate',
#   'election_date': '2014-11-04',
#   'poll_count': 67,
#   'last_updated': '2016-07-08T16:30:11.000Z',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-michigan-senate-land-vs-peters',
#   'estimates': [{'choice': 'Peters',
#     'value': 51.6,
#     'lead_confidence': 100.0,
#     'first_name': 'Gary',
#     'last_name': 'Peters',
#     'party': 'Dem',
#     'incumbent': False},
#    {'choice': 'Land',
#     'value': 39.8,
#     'lead_confidence': 0.0,
#     'first_name': 'Terri Lynn',
#     'last_name': 'Land',
#     'party': 'Rep',
#     'incumbent': False},
#    {'choice': 'Other',
#     'value': 3.98,
#     'lead_confidence': None,
#     'first_name': None,
#     'last_name': None,
#     'party': 'N/A',
#     'incumbent': False}]},
#  {'id': 406,
#   'title': '2014 Arkansas Senate: Cotton vs. Pryor',
#   'slug': '2014-arkansas-senate-cotton-vs-pryor',
#   'topic': '2014-senate',
#   'state': 'AR',
#   'short_title': '2014 Arkansas Senate',
#   'election_date': '2014-11-04',
#   'poll_count': 61,
#   'last_updated': '2016-08-11T21:02:10.000Z',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-arkansas-senate-cotton-vs-pryor',
#   'estimates': [{'choice': 'Cotton',
#     'value': 51.7,
#     'lead_confidence': 100.0,
#     'first_name': 'Tom',
#     'last_name': 'Cotton',
#     'party': 'Rep',
#     'incumbent': False},
#    {'choice': 'Pryor',
#     'value': 45.6,
#     'lead_confidence': 0.0,
#     'first_name': 'Mark',
#     'last_name': 'Pryor',
#     'party': 'Dem',
#     'incumbent': True},
#    {'choice': 'Other',
#     'value': '3.8016113722650173',
#     'lead_confidence': None,
#     'first_name': None,
#     'last_name': None,
#     'party': 'N/A',
#     'incumbent': False},
#    {'choice': 'Undecided',
#     'value': 2.7,
#     'lead_confidence': None,
#     'first_name': None,
#     'last_name': None,
#     'party': 'N/A',
#     'incumbent': False}]},
#  {'id': 402,
#   'title': '2014 Kentucky Senate: McConnell vs. Grimes',
#   'slug': '2014-kentucky-senate-mcconnell-vs-grimes',
#   'topic': '2014-senate',
#   'state': 'KY',
#   'short_title': '2014 Kentucky Senate',
#   'election_date': '2014-11-04',
#   'poll_count': 57,
#   'last_updated': '2016-07-08T16:30:15.000Z',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-kentucky-senate-mcconnell-vs-grimes',
#   'estimates': [{'choice': 'McConnell',
#     'value': 50.1,
#     'lead_confidence': 100.0,
#     'first_name': 'Mitch',
#     'last_name': 'McConnell',
#     'party': 'Rep',
#     'incumbent': True},
#    {'choice': 'Grimes',
#     'value': 44.1,
#     'lead_confidence': 0.0,
#     'first_name': 'Alison Lundergan',
#     'last_name': 'Grimes',
#     'party': 'Dem',
#     'incumbent': False},
#    {'choice': 'Other',
#     'value': 2.9,
#     'lead_confidence': None,
#     'first_name': None,
#     'last_name': None,
#     'party': 'N/A',
#     'incumbent': False}]}]

# %%
### Your code here ###
#for i in info:
 #   for k in i['estimates']:
 #       print(k['first_name'],k['value'],k['incumbent'])
from collections import Counter
states = [election['state'] for election in info]     
title = [election['title'] for election in info]
countstate =Counter(states)
print(countstate)
# Out:
# Counter({'OK': 2, 'SC': 2, 'NH': 2, 'DE': 1, 'MA': 1, 'RI': 1, 'MT': 1, 'HI': 1, 'KS': 1, 'WY': 1, 'TN': 1, 'ID': 1, 'NJ': 1, 'NM': 1, 'TX': 1, 'MN': 1, 'ME': 1, 'SD': 1, 'NE': 1, 'GA': 1, 'OR': 1, 'MS': 1, 'IA': 1, 'AK': 1, 'IL': 1, 'CO': 1, 'VA': 1, 'NC': 1, 'WV': 1, 'LA': 1, 'MI': 1, 'AR': 1, 'KY': 1})

# %%
print(countstate.most_common(4))
index = [state[0] for state in countstate.most_common(3)]
print(index)
# Out:
# [('OK', 2), ('SC', 2), ('NH', 2), ('DE', 1)]
# ['OK', 'SC', 'NH']

# %%
for em in index:
    ind = [i for i,x in enumerate(states) if x ==em]
    for i in ind:
        print(title[i])
# Out:
# 2014 Oklahoma Senate: Lankford vs. Johnson
# 2014 Oklahoma Senate: Inhofe vs. Silverstein
# 2014 South Carolina Senate: Scott vs. Dickerson
# 2014 South Carolina Senate: Graham vs. Hutto
# 2014 New Hampshire Senate: Bass vs. Shaheen
# 2014 New Hampshire Senate: Brown vs. Shaheen

# %%
removeset = set([6, 36])
infoClean = [v for i, v in enumerate(info) if i not in removeset]

# %%
len(infoClean)
# Out:
# 35

# %% [markdown]
# ** Your answer here: **
# there are more than 2 candidate in a state race

# %% [markdown]
# #### Problem 1(c)
#
# Create a dictionary of pandas DataFrames called `polls` keyed by the name of the election (a string). Each value in the dictionary should contain the polls for one of the races.

# %%
url =[election['url'] + '.csv' for election in infoClean]

# %%
import io,sys
def build_frame(url):

    source = requests.get(url).text
    s = io.StringIO(source) 
    return pd.DataFrame.from_csv(s, index_col=None).convert_objects(
            convert_dates="coerce", convert_numeric=True)

# %%
import requests
polls = dict((election['slug'], build_frame(election['url']+'.csv')) for election in infoClean)
# Out:
# /Users/xinzhao/Applications/anaconda3/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   import sys

# %%
polls['2014-massachusetts-senate-herr-vs-markey']#.iloc[:,0].size
# Out:
#                        Pollster Start Date   End Date Entry Date/Time (ET)  \
# 0                          WNEU 2014-10-21 2014-10-30  2014-10-31 20:58:04
# 1         Suffolk/Boston Herald 2014-10-27 2014-10-29  2014-10-30 17:58:34
# 2   UMass Amherst/WBZ-TV/YouGov 2014-10-20 2014-10-27  2014-10-31 22:21:20
# 3                  MassINC/WBUR 2014-10-22 2014-10-25  2014-10-28 19:16:55
# 4                CBS/NYT/YouGov 2014-10-16 2014-10-23  2014-10-26 15:07:08
# 5                  MassINC/WBUR 2014-10-01 2014-10-04  2014-10-08 12:09:07
# 6                CBS/NYT/YouGov 2014-09-20 2014-10-01  2014-10-05 15:51:44
# 7         Suffolk/Boston Herald 2014-09-25 2014-09-28  2014-09-29 16:38:59
# 8                          WNEU 2014-09-20 2014-09-28  2014-09-29 21:31:53
# 9                  MassINC/WBUR 2014-09-16 2014-09-21  2014-09-24 11:14:38
# 10                    Rasmussen 2014-09-16 2014-09-17  2014-09-18 20:18:43
# 11    Boston Globe/SocialSphere 2014-09-14 2014-09-16  2014-09-19 15:49:13
# 12               CBS/NYT/YouGov 2014-07-05 2014-07-24  2014-07-28 18:29:27
#
#     Number of Observations     Population        Mode  Markey  Herr  \
# 0                      430  Likely Voters  Live Phone    54.0  34.0
# 1                      500  Likely Voters  Live Phone    49.0  34.0
# 2                      591  Likely Voters    Internet    53.0  37.0
# 3                      494  Likely Voters  Live Phone    57.0  32.0
# 4                     2218  Likely Voters    Internet    54.0  32.0
# 5                      504  Likely Voters  Live Phone    56.0  30.0
# 6                     2389  Likely Voters    Internet    54.0  31.0
# 7                      500  Likely Voters  Live Phone    54.0  30.0
# 8                      416  Likely Voters  Live Phone    56.0  34.0
# 9                      502  Likely Voters  Live Phone    58.0  30.0
# 10                     750  Likely Voters  IVR/Online    49.0  31.0
# 11                     407  Likely Voters  Live Phone    53.0  27.0
# 12                    1846  Likely Voters    Internet    61.0  34.0
#
#     Undecided  Other                                       Pollster URL  \
# 0        12.0    0.0  http://elections.huffingtonpost.com/pollster/p...
# 1        17.0    NaN  http://elections.huffingtonpost.com/pollster/p...
# 2         9.0    NaN  http://elections.huffingtonpost.com/pollster/p...
# 3         9.0    1.0  http://elections.huffingtonpost.com/pollster/p...
# 4        14.0    0.0  http://elections.huffingtonpost.com/pollster/p...
# 5        13.0    1.0  http://elections.huffingtonpost.com/pollster/p...
# 6         1.0    0.0  http://elections.huffingtonpost.com/pollster/p...
# 7        16.0    NaN  http://elections.huffingtonpost.com/pollster/p...
# 8        10.0    NaN  http://elections.huffingtonpost.com/pollster/p...
# 9        11.0    1.0  http://elections.huffingtonpost.com/pollster/p...
# 10       15.0    5.0  http://elections.huffingtonpost.com/pollster/p...
# 11       21.0    NaN  http://elections.huffingtonpost.com/pollster/p...
# 12        2.0    3.0  http://elections.huffingtonpost.com/pollster/p...
#
#                                            Source URL     Partisan  \
# 0   http://www1.wne.edu/assets/184/WNE_Polling_-_M...  Nonpartisan
# 1   http://www.suffolk.edu/documents/SUPRC/10_30_2...  Nonpartisan
# 2   https://cbsboston.files.wordpress.com/2014/10/...  Nonpartisan
# 3   http://www.wbur.org/2014/10/28/final-baker-coa...  Nonpartisan
# 4   https://today.yougov.com/news/2014/09/07/battl...  Nonpartisan
# 5   https://www.scribd.com/doc/242219701/Topline-W...  Nonpartisan
# 6   https://today.yougov.com/news/2014/09/07/battl...  Nonpartisan
# 7   http://www.suffolk.edu/news/55991.php#.VCmKD4B...  Nonpartisan
# 8   http://www1.wne.edu/assets/184/Polling_-_MA_Go...  Nonpartisan
# 9   http://www.wbur.org/2014/09/24/poll-coakley-ho...  Nonpartisan
# 10  http://www.rasmussenreports.com/public_content...  Nonpartisan
# 11  https://s3.amazonaws.com/s3.documentcloud.org/...  Nonpartisan
# 12  http://mobile.nytimes.com/2014/07/28/upshot/ex...  Nonpartisan
#
#    Affiliation  Question Text  Question Iteration
# 0         None            NaN                   1
# 1         None            NaN                   1
# 2         None            NaN                   1
# 3         None            NaN                   1
# 4         None            NaN                   1
# 5         None            NaN                   1
# 6         None            NaN                   1
# 7         None            NaN                   1
# 8         None            NaN                   1
# 9         None            NaN                   1
# 10        None            NaN                   1
# 11        None            NaN                   1
# 12        None            NaN                   1

# %% [markdown]
# #### Problem 1(d)
#
# Now create a master table information containing information about each race. Create a pandas DataFrame called `candidates` with rows containing information about each race. The `candidates` DataFrame should have the following columns:
#
# 1. `State` = the state where the race is being held
# 2. `R` = name of republican candidate
# 3. `D` = name of non-republican candidate (Democrate or Independent)
# 4. `incumbent` = R, D or NA
#
# **Hint**: You will need a considerable amount of data wrangling for this.

# %%
### Your code here ###
def trans_name(x):
    if x =='Rep': return 'R'
    elif x =='Dem': return 'D'
    else: return 'NA'
candidates = pd.DataFrame()
#for k,v in polls:
#candidates['State'] = [election['state'] for election in infoClean]
tmp = [ election['estimates'] for election in infoClean]
#candidates['R']= [ e['first_name']+' '+e['last_name'] for ee in tmp for e in ee if e['party']=='Rep']
#candidates['D']= [ e['first_name']+' '+e['last_name'] for ee in tmp for e in ee if e['party']=='Dem']                   
#candidates['incumbent']=[trans_name(e['party']) for ee in tmp for e in ee if e['incumbent']==True ]

# %%
rows = []
for i,dt in enumerate(infoClean):
    x = dt['estimates'][0:2]
    #print(dt)
    if not x:
        tmp = dt['url'].split('-')+['vs']
        print(tmp)
        j = tmp.index('vs')
        if j!=len(tmp)-1:
            R = tmp[j-1].capitalize()
            D = tmp[j+1].capitalize()
            incumbent = 'NA'
            #if no data means race is decided
    else:
        tmp = [x[0]['party'],x[1]['party']]
        R = x[tmp.index('Rep')]['last_name']
        idx = [k for k in range(len(tmp)) if tmp[k]!='Rep'][0]
        D = x[idx]['last_name']
        tmp2 = [x[0]['incumbent'],x[1]['incumbent']]
        tmp2+=[True]
        incumbent = 'NA'
        if tmp2.index(True)!=2:
            incumbent = tmp[tmp2.index(True)]
            
    rows.append((dt['state'], R, D, incumbent))
    
candidates = pd.DataFrame(rows, columns=["State", "R", "D", "incumbent"])
        
#remove second last name 
candidates.R = [candidate.split(' ')[-1] for candidate in candidates.R]
candidates
# Out:
# ['http://elections.huffingtonpost.com/pollster/2014', 'rhode', 'island', 'senate', 'zaccaria', 'vs', 'reed', 'vs']
# ['http://elections.huffingtonpost.com/pollster/2014', 'new', 'hampshire', 'senate', 'bass', 'vs', 'shaheen', 'vs']
#    State          R            D incumbent
# 0     DE       Wade        Coons       Dem
# 1     MA       Herr       Markey       Dem
# 2     RI   Zaccaria         Reed        NA
# 3     MT     Daines       Curtis        NA
# 4     OK   Lankford      Johnson        NA
# 5     HI    Cavasso       Schatz       Dem
# 6     WY       Enzi        Hardy       Rep
# 7     TN  Alexander         Ball       Rep
# 8     ID      Risch     Mitchell       Rep
# 9     NJ       Bell       Booker       Dem
# 10    NM        Weh        Udall       Dem
# 11    OK     Inhofe  Silverstein       Rep
# 12    SC      Scott    Dickerson       Rep
# 13    SC     Graham        Hutto       Rep
# 14    TX     Cornyn      Alameel       Rep
# 15    MN   McFadden      Franken       Dem
# 16    ME    Collins      Bellows       Rep
# 17    SD     Rounds      Weiland        NA
# 18    NE      Sasse       Domina        NA
# 19    GA     Perdue         Nunn        NA
# 20    OR      Wehby      Merkley       Dem
# 21    MS    Cochran     Childers       Rep
# 22    IA      Ernst       Braley        NA
# 23    AK   Sullivan       Begich       Dem
# 24    IL   Oberweis       Durbin       Dem
# 25    CO    Gardner        Udall       Dem
# 26    VA  Gillespie       Warner       Dem
# 27    NC     Tillis        Hagan       Dem
# 28    NH       Bass      Shaheen        NA
# 29    WV     Capito      Tennant        NA
# 30    NH      Brown      Shaheen       Dem
# 31    LA    Cassidy     Landrieu       Dem
# 32    MI       Land       Peters        NA
# 33    AR     Cotton        Pryor       Dem
# 34    KY  McConnell       Grimes       Rep

# %% [markdown]
# ## Problem 2: Confidence Intervals
#
# Compute a 99% confidence interval for each state.

# %% [markdown]
# #### Problem 2(a)
#
# Assume you have $M$ polls with sample sizes $n_1, \dots, n_M$. If the polls are independent, what is the average of the variances of each poll if the true proportion is $p$?

# %% [markdown]
# ** Your answer here: **  (1/n1+...+1/nm)p*(1-p)/m

# %% [markdown]
# #### Problem 2(b)
#
# Compute the square root of these values in Problem 2(a) for the republican candidates in each race. Then, compute the standard deviations of the observed poll results for each race.

# %%
### Your code here ###
results =[]
stds=[]
totals=[]
for name in candidates.R:
    result =0
    for v in polls.values():
        if name in v.columns:
            std=np.std(v[name]/100)
            total=v.iloc[:,0].size
            for p,n in zip(v[name],v['Number of Observations']):
                result +=p*(100-p)/10000/n
    result/= total
    results.append(np.sqrt(result))
    results = results
    stds.append(std)
    totals.append(total)
results
# Out:
# [0.01924692152747528,
#  0.018970941468153677,
#  0.015517120928343491,
#  0.021129035087634883,
#  0.01766149309574479,
#  0.014119539761890539,
#  0.024787410439064624,
#  0.016218436567900906,
#  0.0192849069120808,
#  0.015986375590974416,
#  0.01751919412308524,
#  0.017616677267794617,
#  0.014849892769466569,
#  0.01562379870141054,
#  0.014569086605880932,
#  0.01694235435562249,
#  0.01852368458052701,
#  0.019996388957024307,
#  0.01778914645654338,
#  0.01730407278877138,
#  0.01813592088993929,
#  0.018543798420525132,
#  0.017052889515157394,
#  0.019797364549536435,
#  0.015305883661606614,
#  0.018049758688500728,
#  0.016381219767166267,
#  0.018559116514279262,
#  0.01706337344718028,
#  0.019470436762224222,
#  0.018542713533428647,
#  0.019096484763590712,
#  0.0176871713873475,
#  0.018721292955727296,
#  0.01726376128152261]

# %% [markdown]
# #### Problem 2(c)
#
# Plot observed versus theoretical (average of the theoretical SDs) with the area of the point proportional to number of polls. How do these compare?

# %%
### Your code here ###
df =pd.DataFrame([results,stds,totals],index=['average variable','std','number of polls'])

# %%
df = df.T

# %%
#plt.plot(df['std'])
#plt.xticks(plt.xticks()[0],df['number of polls'])
#plt.show()
#plt.plot(df['average variable'])
#plt.xticks(plt.xticks()[0],df['number of polls'])
#plt.show()
plt.scatter(df['average variable'],df['std'],s=df['number of polls'],marker='o')
currentx = plt.xlim()
currenty = plt.ylim()
plt.plot((0,1),(0,1), c='black', linewidth=1)
plt.xlim(currentx)
plt.ylim(currenty)
plt.show()

# %% [markdown]
# ** Your answer here: **

# %%
obs is higher then theory sd

# %% [markdown]
# #### Problem 2(d)
#
# Repeat Problem 2(c) but include only the most recent polls from the last two months. Do they match better or worse or the same? Can we just trust the theoretical values?

# %%
### Your code here ###
results =[]
stds=[]
totals=[]
for name in candidates.R:
    result =0
    for v in polls.values():
        if name in v.columns:
            time = v['Entry Date/Time (ET)'].max()
            diff = v['End Date'].apply(lambda x: (time-x).days)
            new_v=v[diff<=60]
            std=np.std(new_v[name]/100)
            total=new_v.iloc[:,0].size
            for p,n in zip(new_v[name],new_v['Number of Observations']):
                result +=p*(100-p)/10000/n
    result/= total
    results.append(np.sqrt(result))
    results = results
    stds.append(std)
    totals.append(total)

# %%
plt.scatter(results,stds,s=totals,marker='o')
currentx = plt.xlim()
currenty = plt.ylim()
plt.plot((0,1),(0,1), c='black', linewidth=1)
plt.xlim(currentx)
plt.ylim(currenty)
plt.show()

# %% [markdown]
# ** Your answer here: **

# %% [markdown]
# #### Problem 2(e)
#
# Create a scatter plot with each point representing one state. Is there one or more races that are outlier in that it they have much larger variabilities than expected ? Explore the original poll data and explain why the discrepancy?

# %%
### Your code here ### 
plt.scatter(df['average variable'],df['std'],marker="o", s=0)
plt.xlabel("Theoretical Standard Deviation")
plt.ylabel("Observed Standard Deviation")
plt.title("Observed vs Theoretical Polling SD's")
for i in range(len(df['average variable'])):
    plt.text(df['average variable'][i], df['std'][i], candidates.loc[i,'State'])
currentx = plt.xlim()
currenty = plt.ylim()
plt.plot((0,1),(0,1), c='black', linewidth=1)
plt.xlim(currentx)
plt.ylim(currenty)
plt.show()

# %% [markdown]
# ** Your answer here: **

# %% [markdown]
# #### Problem 2(f)
#
# Construct confidence intervals for the difference in each race. Use either theoretical or data driven estimates of the standard error depending on your answer to this question. Use the results in Problem 2(e), to justify your choice.

# %%
### Your code here ###
# mean +- 2.58 SD 
def calc_diffs(infoClean, polls, numdays=None):
    rows = []
    for ii,election in enumerate(infoClean):
        polls_key = election['slug']
        this_election = polls[polls_key]            
        npoll = this_election.shape[0]
        diffs = (this_election[candidates.R.loc[ii]]-this_election[candidates.D.loc[ii]])/100        
        mean_diff = np.mean(diffs)
        obs_se = np.std(diffs)/np.sqrt(npoll)
        rows.append((polls_key, mean_diff, obs_se, mean_diff-obs_se*2.58, mean_diff+obs_se*2.58))
    return rows

ests = pd.DataFrame(calc_diffs(infoClean, polls), columns=['race', 'mean', 'se', 'lower', 'upper'])
print ("Unsorted:")
print (ests[['race', 'lower', 'upper']])
ests.sort_values("mean", inplace=True)
print ("Sorted:")
print (ests[['race', 'lower', 'upper']])

plt.errorbar(range(ests.shape[0]), ests['mean'], yerr=ests['se']*2.58, fmt='o')
plt.xticks(range(ests.shape[0]), ests['race'].values, rotation=90)
plt.xlim(-1, ests.shape[0])
plt.axhline(0, linewidth=1, color='black')
plt.xlabel("Race")
plt.ylabel("Difference")
plt.title("99% Confidence intervals for Diff (Rep-Dem) for each race")
plt.show()
# Out:
# Unsorted:
#                                              race     lower     upper
# 0              2014-delaware-senate-wade-vs-coons -0.221629 -0.126371
# 1        2014-massachusetts-senate-herr-vs-markey -0.253322 -0.195908
# 2       2014-rhode-island-senate-zaccaria-vs-reed -0.479570 -0.230430
# 3            2014-montana-senate-daines-vs-curtis  0.144632  0.198225
# 4        2014-oklahoma-senate-lankford-vs-johnson  0.266694  0.355806
# 5            2014-hawaii-senate-cavasso-vs-schatz -0.493233 -0.314267
# 6                             2014-wyoming-senate  0.362462  0.533538
# 7         2014-tennessee-senate-alexander-vs-ball  0.144901  0.235099
# 8             2014-idaho-senate-risch-vs-mitchell  0.230231  0.366436
# 9           2014-new-jersey-senate-bell-vs-booker -0.164362 -0.110305
# 10            2014-new-mexico-senate-weh-vs-udall -0.182630 -0.109036
# 11     2014-oklahoma-senate-inhofe-vs-silverstein  0.268602  0.371398
# 12  2014-south-carolina-senate-scott-vs-dickerson  0.168389  0.261611
# 13     2014-south-carolina-senate-graham-vs-hutto  0.127196  0.172804
# 14            2014-texas-senate-cornyn-vs-alameel  0.160375  0.221625
# 15      2014-minnesota-senate-mcfadden-vs-franken -0.127646 -0.088544
# 16           2014-maine-senate-collins-vs-bellows  0.265348  0.382152
# 17     2014-south-dakota-senate-rounds-vs-weiland  0.100054  0.159946
# 18           2014-nebraska-senate-sasse-vs-domina  0.204777  0.285223
# 19             2014-georgia-senate-perdue-vs-nunn  0.003056  0.031846
# 20            2014-oregon-senate-wehby-vs-merkley -0.171230 -0.095086
# 21    2014-mississippi-senate-cochran-vs-childers  0.125796  0.184204
# 22               2014-iowa-senate-ernst-vs-braley -0.015374  0.014647
# 23          2014-alaska-senate-sullivan-vs-begich -0.026802  0.021087
# 24        2014-illinois-senate-oberweis-vs-durbin -0.150401 -0.097599
# 25          2014-colorado-senate-gardner-vs-udall -0.007714  0.018825
# 26       2014-virginia-senate-gillespie-vs-warner -0.190260 -0.118831
# 27     2014-north-carolina-senate-tillis-vs-hagan -0.037483 -0.014096
# 28      2014-new-hampshire-senate-bass-vs-shaheen -0.210810 -0.095857
# 29    2014-west-virginia-senate-capito-vs-tennant  0.100469  0.180960
# 30     2014-new-hampshire-senate-brown-vs-shaheen -0.068833 -0.038909
# 31      2014-louisiana-senate-cassidy-vs-landrieu  0.010544  0.071956
# 32            2014-michigan-senate-land-vs-peters -0.073150 -0.039089
# 33           2014-arkansas-senate-cotton-vs-pryor -0.001097  0.031261
# 34       2014-kentucky-senate-mcconnell-vs-grimes  0.017166  0.042834
# Sorted:
#                                              race     lower     upper
# 5            2014-hawaii-senate-cavasso-vs-schatz -0.493233 -0.314267
# 2       2014-rhode-island-senate-zaccaria-vs-reed -0.479570 -0.230430
# 1        2014-massachusetts-senate-herr-vs-markey -0.253322 -0.195908
# 0              2014-delaware-senate-wade-vs-coons -0.221629 -0.126371
# 26       2014-virginia-senate-gillespie-vs-warner -0.190260 -0.118831
# 28      2014-new-hampshire-senate-bass-vs-shaheen -0.210810 -0.095857
# 10            2014-new-mexico-senate-weh-vs-udall -0.182630 -0.109036
# 9           2014-new-jersey-senate-bell-vs-booker -0.164362 -0.110305
# 20            2014-oregon-senate-wehby-vs-merkley -0.171230 -0.095086
# 24        2014-illinois-senate-oberweis-vs-durbin -0.150401 -0.097599
# 15      2014-minnesota-senate-mcfadden-vs-franken -0.127646 -0.088544
# 32            2014-michigan-senate-land-vs-peters -0.073150 -0.039089
# 30     2014-new-hampshire-senate-brown-vs-shaheen -0.068833 -0.038909
# 27     2014-north-carolina-senate-tillis-vs-hagan -0.037483 -0.014096
# 23          2014-alaska-senate-sullivan-vs-begich -0.026802  0.021087
# 22               2014-iowa-senate-ernst-vs-braley -0.015374  0.014647
# 25          2014-colorado-senate-gardner-vs-udall -0.007714  0.018825
# 33           2014-arkansas-senate-cotton-vs-pryor -0.001097  0.031261
# 19             2014-georgia-senate-perdue-vs-nunn  0.003056  0.031846
# 34       2014-kentucky-senate-mcconnell-vs-grimes  0.017166  0.042834
# 31      2014-louisiana-senate-cassidy-vs-landrieu  0.010544  0.071956
# 17     2014-south-dakota-senate-rounds-vs-weiland  0.100054  0.159946
# 29    2014-west-virginia-senate-capito-vs-tennant  0.100469  0.180960
# 13     2014-south-carolina-senate-graham-vs-hutto  0.127196  0.172804
# 21    2014-mississippi-senate-cochran-vs-childers  0.125796  0.184204
# 3            2014-montana-senate-daines-vs-curtis  0.144632  0.198225
# 7         2014-tennessee-senate-alexander-vs-ball  0.144901  0.235099
# 14            2014-texas-senate-cornyn-vs-alameel  0.160375  0.221625
# 12  2014-south-carolina-senate-scott-vs-dickerson  0.168389  0.261611
# 18           2014-nebraska-senate-sasse-vs-domina  0.204777  0.285223
# 8             2014-idaho-senate-risch-vs-mitchell  0.230231  0.366436
# 4        2014-oklahoma-senate-lankford-vs-johnson  0.266694  0.355806
# 11     2014-oklahoma-senate-inhofe-vs-silverstein  0.268602  0.371398
# 16           2014-maine-senate-collins-vs-bellows  0.265348  0.382152
# 6                             2014-wyoming-senate  0.362462  0.533538

# %% [markdown]
# # Problem 3: Prediction and Posterior Probabilities
#
# Perform a Bayesian analysis to predict the probability of Republicans winning in each state then provide a posterior distribution of the number of republicans in the senate.

# %% [markdown]
# #### Problem 3(a)
#
# First, we define a Bayesian model for each race. The prior for the difference $\theta$ between republicans and democtrats will be $N(\mu,\tau^2)$. Say before seeing poll data you have no idea who is going to win, what should $\mu$ be? How about $\tau$, should it be large or small?

# %% [markdown]
# ** Your answer here: ** 0，1

# %% [markdown]
# #### Problem 3(b)
#
# What is the distribution of $d$ conditioned on $\theta$. What is the posterior distribution of $\theta | d$?
#
# **Hint**: Use normal approximation.

# %% [markdown]
# **Your answer here:** prml   $\theta$ ~$N(\mu,\tau^2)$   d|$\theta$  ~$N( $\theta$ ,$\tau$^2/m)$   so
# d∣θ∼N(θ,σ2/M)
# θ∣d∼N(Bμ+(1−B)d,(1−B)σ2/M),B=1/τ2M/σ2+1/τ2

# %% [markdown]
# #### Problem 3(c)
#
# The prior represents what we think before hand. We do not know who is expected to win, so we assume $\mu=0$. For this problem estimate $\tau$ using the observed differences across states (Hint: $\tau$ represents the standard deviation of a typical difference). Compute the posterior mean for each state and plot it against original average. Is there much change? Why or why not?

# %%
### Your code here ###
tau = np.std(ests['mean'])
B = (1/tau**2)/(1/ests['se']**2+1/tau**2)
ests['mu_post'] = (1-B)*ests['mean']

plt.scatter(ests['mean'], ests['mu_post'], s=50)
plt.title("Bayes vs. Raw Poll Averages")
plt.xlabel("Raw Average")
plt.ylabel("Bayes")

currentx = plt.xlim()
currenty = plt.ylim()
plt.plot((-1,1),(-1,1), c='black', linewidth=1)
plt.xlim(currentx)
plt.ylim(currenty)
plt.show()

# %% [markdown]
# **Your answer here:**

# %% [markdown]
# #### Problem 3(d)
#
# For each state, report a probabilty of Republicans winning. How does your answer here compare to the other aggregators?

# %%
### Your code here ###
ests['sd_post'] = np.sqrt((1-B)*ests['se']**2)
import scipy.stats
ests['R_win_prob'] = 1-scipy.stats.norm.cdf(0, loc=ests['mu_post'], scale=ests['sd_post'])
ests[['race','R_win_prob']].sort_values('R_win_prob')
# Out:
#                                              race    R_win_prob
# 5            2014-hawaii-senate-cavasso-vs-schatz  0.000000e+00
# 30     2014-new-hampshire-senate-brown-vs-shaheen  0.000000e+00
# 32            2014-michigan-senate-land-vs-peters  0.000000e+00
# 15      2014-minnesota-senate-mcfadden-vs-franken  0.000000e+00
# 24        2014-illinois-senate-oberweis-vs-durbin  0.000000e+00
# 9           2014-new-jersey-senate-bell-vs-booker  0.000000e+00
# 20            2014-oregon-senate-wehby-vs-merkley  0.000000e+00
# 26       2014-virginia-senate-gillespie-vs-warner  0.000000e+00
# 0              2014-delaware-senate-wade-vs-coons  0.000000e+00
# 1        2014-massachusetts-senate-herr-vs-markey  0.000000e+00
# 10            2014-new-mexico-senate-weh-vs-udall  0.000000e+00
# 2       2014-rhode-island-senate-zaccaria-vs-reed  4.621858e-13
# 28      2014-new-hampshire-senate-bass-vs-shaheen  3.980039e-12
# 27     2014-north-carolina-senate-tillis-vs-hagan  6.405634e-09
# 23          2014-alaska-senate-sullivan-vs-begich  3.792265e-01
# 22               2014-iowa-senate-ernst-vs-braley  4.750923e-01
# 25          2014-colorado-senate-gardner-vs-udall  8.598894e-01
# 33           2014-arkansas-senate-cotton-vs-pryor  9.918885e-01
# 19             2014-georgia-senate-perdue-vs-nunn  9.991155e-01
# 31      2014-louisiana-senate-cassidy-vs-landrieu  9.997295e-01
# 34       2014-kentucky-senate-mcconnell-vs-grimes  1.000000e+00
# 11     2014-oklahoma-senate-inhofe-vs-silverstein  1.000000e+00
# 4        2014-oklahoma-senate-lankford-vs-johnson  1.000000e+00
# 8             2014-idaho-senate-risch-vs-mitchell  1.000000e+00
# 18           2014-nebraska-senate-sasse-vs-domina  1.000000e+00
# 12  2014-south-carolina-senate-scott-vs-dickerson  1.000000e+00
# 14            2014-texas-senate-cornyn-vs-alameel  1.000000e+00
# 7         2014-tennessee-senate-alexander-vs-ball  1.000000e+00
# 3            2014-montana-senate-daines-vs-curtis  1.000000e+00
# 21    2014-mississippi-senate-cochran-vs-childers  1.000000e+00
# 13     2014-south-carolina-senate-graham-vs-hutto  1.000000e+00
# 29    2014-west-virginia-senate-capito-vs-tennant  1.000000e+00
# 17     2014-south-dakota-senate-rounds-vs-weiland  1.000000e+00
# 16           2014-maine-senate-collins-vs-bellows  1.000000e+00
# 6                             2014-wyoming-senate  1.000000e+00

# %% [markdown]
# **Your answer here:**

# %% [markdown]
# #### Problem 3(e)
#
# Use the posterior distributions in a Monte Carlo simulation to generate election results. In each simulation compute the total number of seats the Republican control. Show a histogram of these results.

# %%
### Your code here ###
num_states = ests.shape[0]
NSIM = 10000
simarr = np.zeros(NSIM, dtype=int)
for i in range(NSIM):
    simulated = 30 + np.sum(np.random.normal(ests['mu_post'], scale=ests['sd_post'], size =num_states) > 0 )
    simarr[i] = int(simulated)
plt.hist(simarr, bins=range(min(simarr)-1, max(simarr)+3))
plt.xlabel('Number of Seats in Republican Control')
plt.ylabel('Frequency')
plt.title('Monte Carlo simulation of Number of Seats in Republican Control')
plt.show()

# %% [markdown]
# ## Problem 4
#
# Predict the results for the 2014 Midterm Elections. We will have a three competitions with the terms for scoring entries described above. For both questions below, **explain** or provide commentary on how you arrived at your predictions including code.
#
# **Hint**: Use election results from 2010, 2012 to build and test models.

# %% [markdown]
# #### Problem 4(a)
#
# Predict the number of Republican senators. You may provide an interval. Smallest interval that includes the election day result wins.
#
# **Note**: we want the total so add the numbers of those that are not up for election.

# %%
### Your code here ###
ests = pd.DataFrame(calc_diffs(infoClean, polls,), columns=['race', 'mean', 'se', 'lower', 'upper'])

# %% [markdown]
# **Provide an explanation of methodology here**:

# %% [markdown]
# #### Problem 4(b)
#
# Predict the R-D difference in each state. The predictions that minimize the residual sum of squares between predicted and observed differences wins.

# %% [markdown]
# **Provide an explanation of methodology here**:

# %% [markdown]
# #### Problem 4(c)
#
# Report a confidence interval for the R-D difference in each state. If the election day result falls outside your confidence interval in more than two states you are eliminated. For those surviving this cutoff, we will add up the size of all confidence intervals and sum. The smallest total length of confidence interval wins.
#
# **Note**: you can use Bayesian credible intervals or whatever else you want.

# %%
### Your code here ###

# %% [markdown]
# **Provide an explanation of methodology here**:

# %% [markdown]
# # Submission Instructions
#
# To submit your homework, create a folder named **lastname_firstinitial_hw#** and place your IPython notebooks, data files, and any other files in this folder. Your IPython Notebooks should be completely executed with the results visible in the notebook. We should not have to run any code.  Compress the folder (please use .zip compression) and submit to the CS109 dropbox in the appropriate folder. *If we cannot access your work because these directions are not followed correctly, we will not grade your work.*
